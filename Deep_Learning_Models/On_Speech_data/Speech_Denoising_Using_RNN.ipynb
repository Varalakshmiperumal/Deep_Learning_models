# %%
import os, glob, math, random
import zipfile
import numpy as np
import librosa
import soundfile as sf
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras import layers, models
import soundfile as sf

# %%
zip_path = "/content/homework3.zip"
extract_to = "/content/timit-homework"
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

# %% [markdown]
# # Loading DataSet Training

# %%
zip_path = "/content/homework3.zip"
extract_folder = "timit-homework"


tr_files_noisy = sorted(glob.glob(os.path.join('/content/timit-homework/timit-homework', 'tr', "trx*.wav")))

tr_files_clean = sorted(glob.glob(os.path.join('/content/timit-homework/timit-homework', 'tr', "trs*.wav")))

tr_files_noise = sorted(glob.glob(os.path.join('/content/timit-homework/timit-homework', 'tr', "trn*.wav")))

# %% [markdown]
# # Create STFT of the training signal

# %%
noisy = []
clean =  []
noise = []
ts = []
v = []

for file in tr_files_noisy:
  s, sr=librosa.load(file, sr=None)
  S=librosa.stft(s, n_fft=1024, hop_length=513)
  S = np.abs(S)
  noisy.append(S)

for file in tr_files_clean:
  s, sr=librosa.load(file, sr=None)
  S=librosa.stft(s, n_fft=1024, hop_length=513)
  S = np.abs(S)
  clean.append(S)

for file in tr_files_noise:
  s, sr=librosa.load(file, sr=None)
  S=librosa.stft(s, n_fft=1024, hop_length=513)
  S = np.abs(S)
  noise.append(S)

# %% [markdown]
# #  Ideal Binary Masks (IBM)
#
# $${M(l)}_{f,t} = 1  if  {|{{S^{(l)}}_
#  {tr}}|}_{f,t} > {|N^{(l)}
#  _{tr}|}_{f,t}$$
#  $$ {M(l)}_{f,t} =
#  0 if {|{{S^{(l)}}_
#  {tr}}|}_{f,t} < {|N^{(l)}
#  _{tr}|}_{f,t}$$

# %%
M_tr = []
for clean_spec, noise_spec in zip(clean, noise):
    T = min(clean_spec.shape[1], noise_spec.shape[1])
    M_tr.append((clean_spec[:, :T] > noise_spec[:, :T]).astype(float))

# %% [markdown]
# IBM assumes that each of the time-frequency bin at (f,t), an element of the X matrix, is from
# either speech or noise
#
# $$ {{S}^{(l)}}_{tr} = {M}^{(l)} ⊙{X}^{(l)}$$

# %%
IBM_S = []

for i,j in zip(noisy, M_tr):
  S_hat = i * j
  IBM_S.append(S_hat)

# %%
seq_len = 100
X_seq, Y_seq = [], []
freq_bins = IBM_S[0].shape[0]

for X, M in zip(IBM_S, clean):
    T = X.shape[1]
    for start in range(0, T, seq_len):
        end = min(start + seq_len, T)

        current_X = X[:, start:end].T
        current_M = M[:, start:end].T

        if current_X.shape[0] < seq_len:
            padding_length = seq_len - current_X.shape[0]
            current_X = np.pad(current_X, ((0, padding_length), (0, 0)), 'constant', constant_values=0.0)
            current_M = np.pad(current_M, ((0, padding_length), (0, 0)), 'constant', constant_values=0.0)

        X_seq.append(current_X)
        Y_seq.append(current_M)

X_seq = np.array(X_seq, dtype=np.float32)
M_seq = np.array(Y_seq, dtype=np.float32)

print("X_seq:", X_seq.shape)
print("M_seq:", M_seq.shape)
# Out:
# X_seq: (1690, 100, 513)
# M_seq: (1690, 100, 513)

# %% [markdown]
# #  LSTM model

# %%
model = models.Sequential([
    layers.Masking(mask_value=0.0, input_shape=(None, freq_bins)),  # None allows variable timesteps
    layers.LSTM(256, return_sequences=True, dropout=0.15, recurrent_dropout=0.05),
    layers.LSTM(128, return_sequences=True, dropout=0.1, recurrent_dropout=0.0),
    layers.TimeDistributed(layers.Dense(freq_bins))  # output per timestep, same dim as input
])

opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ masking_1 (Masking)             │ (None, None, 513)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, None, 256)      │       788,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, None, 128)      │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, None, 513)      │        66,177 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,051,777 (4.01 MB)
#  Trainable params: 1,051,777 (4.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
batch_size = 10
epochs = 5

for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs}")
    perm = np.random.permutation(len(X_seq))  # shuffle indices
    X_train, y_train = X_seq[perm], M_seq[perm]

    for i in range(0, len(X_train), batch_size):
        X_batch = X_train[i:i+batch_size]
        y_batch = y_train[i:i+batch_size]
        loss = model.train_on_batch(X_batch, y_batch)
        print(f" Batch {i}: loss = {loss[0]:.4f}")
# Out:
# Epoch 1/5
#  Batch 0: loss = 0.0343
#  Batch 10: loss = 0.0329
#  Batch 20: loss = 0.0322
#  Batch 30: loss = 0.0310
#  Batch 40: loss = 0.0302
#  Batch 50: loss = 0.0300
#  Batch 60: loss = 0.0294
#  Batch 70: loss = 0.0290
#  Batch 80: loss = 0.0286
#  Batch 90: loss = 0.0282
#  Batch 100: loss = 0.0279
#  Batch 110: loss = 0.0279
#  Batch 120: loss = 0.0279
#  Batch 130: loss = 0.0277
#  Batch 140: loss = 0.0275
#  Batch 150: loss = 0.0272
#  Batch 160: loss = 0.0271
#  Batch 170: loss = 0.0269
#  Batch 180: loss = 0.0268
#  Batch 190: loss = 0.0267
#  Batch 200: loss = 0.0265
#  Batch 210: loss = 0.0264
#  Batch 220: loss = 0.0262
#  Batch 230: loss = 0.0262
#  Batch 240: loss = 0.0261
#  Batch 250: loss = 0.0260
#  Batch 260: loss = 0.0259
#  Batch 270: loss = 0.0258
#  Batch 280: loss = 0.0257
#  Batch 290: loss = 0.0256
#  Batch 300: loss = 0.0256
#  Batch 310: loss = 0.0254
#  Batch 320: loss = 0.0253
#  Batch 330: loss = 0.0252
#  Batch 340: loss = 0.0251
#  Batch 350: loss = 0.0249
#  Batch 360: loss = 0.0249
#  Batch 370: loss = 0.0247
#  Batch 380: loss = 0.0247
#  Batch 390: loss = 0.0246
#  Batch 400: loss = 0.0245
#  Batch 410: loss = 0.0244
#  Batch 420: loss = 0.0243
#  Batch 430: loss = 0.0242
#  Batch 440: loss = 0.0241
#  Batch 450: loss = 0.0240
#  Batch 460: loss = 0.0239
#  Batch 470: loss = 0.0238
#  Batch 480: loss = 0.0237
#  Batch 490: loss = 0.0236
#  Batch 500: loss = 0.0235
#  Batch 510: loss = 0.0234
#  Batch 520: loss = 0.0234
#  Batch 530: loss = 0.0232
#  Batch 540: loss = 0.0232
#  Batch 550: loss = 0.0231
#  Batch 560: loss = 0.0230
#  Batch 570: loss = 0.0229
#  Batch 580: loss = 0.0228
#  Batch 590: loss = 0.0228
#  Batch 600: loss = 0.0227
#  Batch 610: loss = 0.0226
#  Batch 620: loss = 0.0226
#  Batch 630: loss = 0.0225
h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Loading Validation Signal

# %%
v_files_noisy = sorted(glob.glob(os.path.join('/content/timit-homework/timit-homework', 'v', "vn*.wav")))

v_files_clean = sorted(glob.glob(os.path.join('/content/timit-homework/timit-homework', 'v', "vs*.wav")))

# %%
te_noisy_mags = []
v_noisy_mags = []
v_noisy_stfts_complex = []


current_sr = None
current_n_fft = 1024
current_hop_length = 513

for file in v_files_noisy:
  s, _ = librosa.load(file, sr=current_sr)
  S_complex = librosa.stft(s, n_fft=current_n_fft, hop_length=current_hop_length)
  v_noisy_mags.append(np.abs(S_complex))
  v_noisy_stfts_complex.append(S_complex)

# %% [markdown]
# # Denoising validation signal

# %%
denoised_audio_samples = []

def compute_snr(clean, denoised):
    min_len = min(len(clean), len(denoised))
    clean_trimmed = clean[:min_len]
    denoised_trimmed = denoised[:min_len]

    snr = 10 * np.log10(np.sum(clean_trimmed**2) / np.sum((clean_trimmed - denoised_trimmed)**2))
    return snr


for i in range(100):
    print(v_files_noisy[i])
    s, sr = librosa.load(v_files_noisy[i], sr=current_sr)
    S_complex = librosa.stft(s, n_fft=current_n_fft, hop_length=current_hop_length)
    v_noisy_mags= np.abs(S_complex)
    v_noisy_stfts_complex= S_complex
    noisy_mag_spec = v_noisy_mags
    noisy_complex_spec = v_noisy_stfts_complex

    model_input = np.expand_dims(noisy_mag_spec.T, axis=0)
    predicted_clean_mag_spec_transposed =model.predict(model_input)
    predicted_clean_mag_spec = predicted_clean_mag_spec_transposed.T
    predicted_clean_mag_spec = np.squeeze(predicted_clean_mag_spec)
    min_T = min(predicted_clean_mag_spec.shape[1], noisy_complex_spec.shape[1])
    denoised_complex_spec = predicted_clean_mag_spec[:, :min_T] * np.exp(1j * np.angle(noisy_complex_spec[:, :min_T]))
    denoised_signal = librosa.istft(denoised_complex_spec, hop_length=current_hop_length)
    denoised_audio_samples.append(denoised_signal)
    #sf.write(f'/content/Denoised_signal/denoised_signal_{i}.wav', denoised_signal, sr)


    snr = compute_snr(s, denoised_signal)
    print("SNR (dB) for the first validation sample:", snr)
# Out:
# /content/timit-homework/timit-homework/v/vn0000.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# SNR (dB) for the first validation sample: 4.2049894
# /content/timit-homework/timit-homework/v/vn0001.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# SNR (dB) for the first validation sample: 7.7570705
# /content/timit-homework/timit-homework/v/vn0002.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# SNR (dB) for the first validation sample: 5.5811596
# /content/timit-homework/timit-homework/v/vn0003.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# SNR (dB) for the first validation sample: 7.5560274
# /content/timit-homework/timit-homework/v/vn0004.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# SNR (dB) for the first validation sample: 0.831007
# /content/timit-homework/timit-homework/v/vn0005.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# SNR (dB) for the first validation sample: 3.4391806
# /content/timit-homework/timit-homework/v/vn0006.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# SNR (dB) for the first validation sample: 5.310088
# /content/timit-homework/timit-homework/v/vn0007.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# SNR (dB) for the first validation sample: 5.278285
# /content/timit-homework/timit-homework/v/vn0008.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# SNR (dB) for the first validation sample: 3.9866405
# /content/timit-homework/timit-homework/v/vn0009.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# SNR (dB) for the first validation sample: 8.591869
# /content/timit-homework/timit-homework/v/vn0010.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# SNR (dB) for the first validation sample: 4.1968937
# /content/timit-homework/timit-homework/v/vn0011.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# SNR (dB) for the first validation sample: 8.927191
# /content/timit-homework/timit-homework/v/vn0012.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# SNR (dB) for the first validation sample: 6.274556
# /content/timit-homework/timit-homework/v/vn0013.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# SNR (dB) for the first validation sample: 9.970185
# /content/timit-homework/timit-homework/v/vn0014.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# SNR (dB) for the first validation sample: 0.98218656
# /content/timit-homework/timit-homework/v/vn0015.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# SNR (dB) for the first validation sample: 2.867303
# /content/timit-homework/timit-homework/v/vn0016.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# SNR (dB) for the first validation sample: 5.765172
# /content/timit-homework/timit-homework/v/vn0017.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# SNR (dB) for the first validation sample: 5.6564198
# /content/timit-homework/timit-homework/v/vn0018.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# SNR (dB) for the first validation sample: 5.324711
# /content/timit-homework/timit-homework/v/vn0019.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# SNR (dB) for the first validation sample: 7.968431
# /content/timit-homework/timit-homework/v/vn0020.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# SNR (dB) for the first validation sample: 3.0419824
# /content/timit-homework/timit-homework/v/vn0021.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# SNR (dB) for the first validation sample: 8.369034
# /content/timit-homework/timit-homework/v/vn0022.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# SNR (dB) for the first validation sample: 5.266675
# /content/timit-homework/timit-homework/v/vn0023.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# SNR (dB) for the first validation sample: 9.30807
# /content/timit-homework/timit-homework/v/vn0024.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# SNR (dB) for the first validation sample: 1.1305423
# /content/timit-homework/timit-homework/v/vn0025.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# SNR (dB) for the first validation sample: 3.7321835
# /content/timit-homework/timit-homework/v/vn0026.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# SNR (dB) for the first validation sample: 6.885087
# /content/timit-homework/timit-homework/v/vn0027.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# SNR (dB) for the first validation sample: 4.503742
# /content/timit-homework/timit-homework/v/vn0028.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# SNR (dB) for the first validation sample: 5.235507
# /content/timit-homework/timit-homework/v/vn0029.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# SNR (dB) for the first validation sample: 7.7198277
# /content/timit-homework/timit-homework/v/vn0030.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# SNR (dB) for the first validation sample: 3.0545783
# /content/timit-homework/timit-homework/v/vn0031.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# SNR (dB) for the first validation sample: 7.618568
# /content/timit-homework/timit-homework/v/vn0032.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# SNR (dB) for the first validation sample: 5.4167957
# /content/timit-homework/timit-homework/v/vn0033.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# SNR (dB) for the first validation sample: 9.495388
# /content/timit-homework/timit-homework/v/vn0034.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# SNR (dB) for the first validation sample: 2.4638216
# /content/timit-homework/timit-homework/v/vn0035.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# SNR (dB) for the first validation sample: 3.1935213
# /content/timit-homework/timit-homework/v/vn0036.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# SNR (dB) for the first validation sample: 7.239131
# /content/timit-homework/timit-homework/v/vn0037.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# SNR (dB) for the first validation sample: 5.759472
# /content/timit-homework/timit-homework/v/vn0038.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# SNR (dB) for the first validation sample: 3.6356509
# /content/timit-homework/timit-homework/v/vn0039.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# SNR (dB) for the first validation sample: 7.4973397
# /content/timit-homework/timit-homework/v/vn0040.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# SNR (dB) for the first validation sample: 4.5555396
# /content/timit-homework/timit-homework/v/vn0041.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# SNR (dB) for the first validation sample: 8.4810295
# /content/timit-homework/timit-homework/v/vn0042.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# SNR (dB) for the first validation sample: 5.9169626
# /content/timit-homework/timit-homework/v/vn0043.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# SNR (dB) for the first validation sample: 8.942016
# /content/timit-homework/timit-homework/v/vn0044.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# SNR (dB) for the first validation sample: 2.0424898
# /content/timit-homework/timit-homework/v/vn0045.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# SNR (dB) for the first validation sample: 2.2996244
# /content/timit-homework/timit-homework/v/vn0046.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# SNR (dB) for the first validation sample: 6.968108
# /content/timit-homework/timit-homework/v/vn0047.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# SNR (dB) for the first validation sample: 5.8072624
# /content/timit-homework/timit-homework/v/vn0048.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# SNR (dB) for the first validation sample: 4.4424763
# /content/timit-homework/timit-homework/v/vn0049.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# SNR (dB) for the first validation sample: 7.811153
# /content/timit-homework/timit-homework/v/vn0050.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# SNR (dB) for the first validation sample: 4.5965886
# /content/timit-homework/timit-homework/v/vn0051.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# SNR (dB) for the first validation sample: 7.8531003
# /content/timit-homework/timit-homework/v/vn0052.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# SNR (dB) for the first validation sample: 4.9069405
# /content/timit-homework/timit-homework/v/vn0053.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# SNR (dB) for the first validation sample: 10.114758
# /content/timit-homework/timit-homework/v/vn0054.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# SNR (dB) for the first validation sample: 3.4436316
# /content/timit-homework/timit-homework/v/vn0055.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# SNR (dB) for the first validation sample: 3.0976744
# /content/timit-homework/timit-homework/v/vn0056.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# SNR (dB) for the first validation sample: 4.7710137
# /content/timit-homework/timit-homework/v/vn0057.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# SNR (dB) for the first validation sample: 5.205643
# /content/timit-homework/timit-homework/v/vn0058.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# SNR (dB) for the first validation sample: 2.5037348
# /content/timit-homework/timit-homework/v/vn0059.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# SNR (dB) for the first validation sample: 7.8726397
# /content/timit-homework/timit-homework/v/vn0060.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# SNR (dB) for the first validation sample: 4.6447144
# /content/timit-homework/timit-homework/v/vn0061.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# SNR (dB) for the first validation sample: 8.063766
# /content/timit-homework/timit-homework/v/vn0062.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# SNR (dB) for the first validation sample: 5.8080835
# /content/timit-homework/timit-homework/v/vn0063.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# SNR (dB) for the first validation sample: 8.82406
# /content/timit-homework/timit-homework/v/vn0064.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# SNR (dB) for the first validation sample: 0.6623635
# /content/timit-homework/timit-homework/v/vn0065.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# SNR (dB) for the first validation sample: 3.3951423
# /content/timit-homework/timit-homework/v/vn0066.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# SNR (dB) for the first validation sample: 4.6805816
# /content/timit-homework/timit-homework/v/vn0067.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# SNR (dB) for the first validation sample: 6.035753
# /content/timit-homework/timit-homework/v/vn0068.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# SNR (dB) for the first validation sample: 4.839768
# /content/timit-homework/timit-homework/v/vn0069.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# SNR (dB) for the first validation sample: 7.7490864
# /content/timit-homework/timit-homework/v/vn0070.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# SNR (dB) for the first validation sample: 4.385642
# /content/timit-homework/timit-homework/v/vn0071.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# SNR (dB) for the first validation sample: 8.770117
# /content/timit-homework/timit-homework/v/vn0072.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# SNR (dB) for the first validation sample: 6.077323
# /content/timit-homework/timit-homework/v/vn0073.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# SNR (dB) for the first validation sample: 9.244669
# /content/timit-homework/timit-homework/v/vn0074.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# SNR (dB) for the first validation sample: 2.5041285
# /content/timit-homework/timit-homework/v/vn0075.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# SNR (dB) for the first validation sample: 3.2326725
# /content/timit-homework/timit-homework/v/vn0076.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# SNR (dB) for the first validation sample: 4.7588058
# /content/timit-homework/timit-homework/v/vn0077.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# SNR (dB) for the first validation sample: 4.853409
# /content/timit-homework/timit-homework/v/vn0078.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# SNR (dB) for the first validation sample: 2.9263713
# /content/timit-homework/timit-homework/v/vn0079.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# SNR (dB) for the first validation sample: 8.990187
# /content/timit-homework/timit-homework/v/vn0080.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# SNR (dB) for the first validation sample: 4.280625
# /content/timit-homework/timit-homework/v/vn0081.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# SNR (dB) for the first validation sample: 6.038041
# /content/timit-homework/timit-homework/v/vn0082.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# SNR (dB) for the first validation sample: 5.8471847
# /content/timit-homework/timit-homework/v/vn0083.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# SNR (dB) for the first validation sample: 9.035887
# /content/timit-homework/timit-homework/v/vn0084.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# SNR (dB) for the first validation sample: 3.5438209
# /content/timit-homework/timit-homework/v/vn0085.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# SNR (dB) for the first validation sample: 3.051147
# /content/timit-homework/timit-homework/v/vn0086.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# SNR (dB) for the first validation sample: 4.9823117
# /content/timit-homework/timit-homework/v/vn0087.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# SNR (dB) for the first validation sample: 6.0156107
# /content/timit-homework/timit-homework/v/vn0088.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# SNR (dB) for the first validation sample: 3.621012
# /content/timit-homework/timit-homework/v/vn0089.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# SNR (dB) for the first validation sample: 7.535503
# /content/timit-homework/timit-homework/v/vn0090.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# SNR (dB) for the first validation sample: 4.1682916
# /content/timit-homework/timit-homework/v/vn0091.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# SNR (dB) for the first validation sample: 7.331617
# /content/timit-homework/timit-homework/v/vn0092.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# SNR (dB) for the first validation sample: 6.862986
# /content/timit-homework/timit-homework/v/vn0093.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# SNR (dB) for the first validation sample: 8.974935
# /content/timit-homework/timit-homework/v/vn0094.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# SNR (dB) for the first validation sample: 2.2006025
# /content/timit-homework/timit-homework/v/vn0095.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# SNR (dB) for the first validation sample: 2.2745323
# /content/timit-homework/timit-homework/v/vn0096.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# SNR (dB) for the first validation sample: 4.40283
# /content/timit-homework/timit-homework/v/vn0097.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# SNR (dB) for the first validation sample: 3.6289666
# /content/timit-homework/timit-homework/v/vn0098.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# SNR (dB) for the first validation sample: 3.8489568
# /content/timit-homework/timit-homework/v/vn0099.wav
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# SNR (dB) for the first validation sample: 9.248484

# %%
from google.colab import drive
drive.mount('/content/drive')

from google.colab import files

# !jupyter nbconvert --to html "/content/drive/MyDrive/Colab Notebooks/DLS_HW_3_5.ipynb"
files.download("/content/drive/MyDrive/Colab Notebooks/DLS_HW_3_5.html")
# Out:
# Mounted at /content/drive
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/DLS_HW_3_5.ipynb to html
# [NbConvertApp] Writing 366191 bytes to /content/drive/MyDrive/Colab Notebooks/DLS_HW_3_5.html
